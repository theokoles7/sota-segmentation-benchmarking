# %% [markdown]
# ## CellMap Challenge Dataset
# [< Documentation](./README.md)
#
# This noteboiok explores the CellMap Challenge dataset, containing 22 individual "sub"-datasets. This dataset is provided using the `.zarr` file format.

# %%
"""Open dataset."""

from os     import getenv

from zarr   import Array, open

user:       str =   getenv("USER")\

dataset:    Array = open(
                        f"/home/{user}/Projects/sota-segmentation-benchmarking/data/jrc_cos7-1a/jrc_cos7-1a.zarr",
                        mode =  "r"
                    )
# Print tree.
print(dataset.tree())

# Examine masks.
print(dataset.keys())
# Out:
# /
#  └── recon-1
#      └── labels
#          └── groundtruth
#              ├── crop234
#              │   ├── all
#              │   │   ├── s0 (400, 400, 400) uint8
#              │   │   ├── s1 (200, 200, 200) uint8
#              │   │   ├── s2 (100, 100, 100) uint8
#              │   │   ├── s3 (50, 50, 50) uint8
#              │   │   └── s4 (25, 25, 25) uint8
#              │   ├── bm
#              │   │   ├── s0 (400, 400, 400) uint8
#              │   │   ├── s1 (200, 200, 200) uint8
#              │   │   ├── s2 (100, 100, 100) uint8
#              │   │   ├── s3 (50, 50, 50) uint8
#              │   │   └── s4 (25, 25, 25) uint8
#              │   ├── cell
#              │   │   ├── s0 (400, 400, 400) uint8
#              │   │   ├── s1 (200, 200, 200) uint8
#              │   │   ├── s2 (100, 100, 100) uint8
#              │   │   ├── s3 (50, 50, 50) uint8
#              │   │   └── s4 (25, 25, 25) uint8
#              │   ├── cent
# ...
